# %%
import scanpy as sc
from tifffile import imread
import numpy as np
import pandas as pd

# %%
adata_14mAD = sc.read("14mAD_mousebrain_with_plaque_info.h5ad")
adata_8mAD = sc.read("8mAD_mousebrain_with_plaque_info.h5ad")
adata_4mAD = sc.read("4mAD_mousebrain_with_plaque_info.h5ad")

adata_14mAD.obs.to_csv("14mAD_mousebrain_with_plaque_info_obs.csv")
adata_8mAD.obs.to_csv("8mAD_mousebrain_with_plaque_info_obs.csv")
adata_4mAD.obs.to_csv("4mAD_mousebrain_with_plaque_info_obs.csv")
